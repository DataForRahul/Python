# %% [markdown]
# **Dataset** **Description**

# %% [markdown]
# I have used the fortune500 dataset for this project. I have downloaded this dataset from the Kaggle

# %% [markdown]
# **Import** **Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Ignore** **Warnings**

# %%
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %% [markdown]
# *Import* *Dataset*

# %%
#data = 'C:/datasets/fortune500.csv'

df = pd.read_csv('/content/fortune500.csv')

# %% [markdown]
# *Exploratory data analysis*

# %%
#find the shape of dataset
df.shape
# Out:
# (25500, 5)

# %%
#check top 5 columns of the dataset
df.head(5)
# Out:
#    Year  Rank           Company  Revenue (in millions) Profit (in millions)
# 0  1955     1    General Motors                 9823.5                  806
# 1  1955     2       Exxon Mobil                 5661.4                584.8
# 2  1955     3        U.S. Steel                 3250.4                195.4
# 3  1955     4  General Electric                 2959.1                212.6
# 4  1955     5            Esmark                 2510.8                 19.1

# %%
#summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25500 entries, 0 to 25499
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   25500 non-null  int64
#  1   Rank                   25500 non-null  int64
#  2   Company                25500 non-null  object
#  3   Revenue (in millions)  25500 non-null  float64
#  4   Profit (in millions)   25500 non-null  object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 996.2+ KB

# %% [markdown]
# *Check for missing values*

# %%
#check for null values
df.isnull().sum()
# Out:
# Year                     0
# Rank                     0
# Company                  0
# Revenue (in millions)    0
# Profit (in millions)     0
# dtype: int64

# %%
#all statistical measures
df.describe()
# Out:
#               Year          Rank  Revenue (in millions)
# count  25500.00000  25500.000000           25500.000000
# mean    1980.00000    250.499765            4273.329635
# std       14.71989    144.339963           11351.884979
# min     1955.00000      1.000000              49.700000
# 25%     1967.00000    125.750000             362.300000
# 50%     1980.00000    250.500000            1019.000000
# 75%     1993.00000    375.250000            3871.000000
# max     2005.00000    500.000000          288189.000000

# %%
df.describe(include="all")[["Company","Profit (in millions)"]].head(4)
# Out:
#        Company Profit (in millions)
# count    25500                25500
# unique    1887                 6977
# top        CBS                 N.A.
# freq        57                  369

# %%
df.describe(include="all")
# Out:
#                Year          Rank Company  Revenue (in millions)  \
# count   25500.00000  25500.000000   25500           25500.000000
# unique          NaN           NaN    1887                    NaN
# top             NaN           NaN     CBS                    NaN
# freq            NaN           NaN      57                    NaN
# mean     1980.00000    250.499765     NaN            4273.329635
# std        14.71989    144.339963     NaN           11351.884979
# min      1955.00000      1.000000     NaN              49.700000
# 25%      1967.00000    125.750000     NaN             362.300000
# 50%      1980.00000    250.500000     NaN            1019.000000
# 75%      1993.00000    375.250000     NaN            3871.000000
# max      2005.00000    500.000000     NaN          288189.000000
#
#        Profit (in millions)
# count                 25500
# unique                 6977
# top                    N.A.
# freq                    369
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %% [markdown]
# *Computation of measures of central tendency*

# %%
#mean of Revenue (in millions)
df["Revenue (in millions)"].mean()
# Out:
# 4273.329635294118

# %%
#median of Revenue (in millions)
df["Revenue (in millions)"].median()
# Out:
# 1019.0

# %%
##mode of Revenue (in millions)
df["Revenue (in millions)"].mode()
# Out:
# 0    85.0
# 1    86.2
# 2    90.0
# Name: Revenue (in millions), dtype: float64

# %% [markdown]
# Observation
#
# We can see that mean > median > mode. So, the distribution of Revenue (in millions) is positively skewed. I will plot its distribution to confirm the same.

# %% [markdown]
# **Plot the distribution**

# %%
data = df['Revenue (in millions)']

sns.distplot(data, bins=10, hist=True, kde=True, label = 'Revenue (in millions)')
# Out:
# <Axes: xlabel='Revenue (in millions)', ylabel='Density'>

# %% [markdown]
# plot confirms that the Revenue (in millions) is positively skewed.

# %% [markdown]
# **Computation of measures of dispersion or variability**
#
# In this section, I will compute the measures of dispersion or variability - minimum and maximum values, range, variance, standard-deviation, IQR.
#
# Again, I will use the Revenue (in millions) variable for calculations.

# %%
# check min of Revenue (in millions)
df["Revenue (in millions)"].min()
# Out:
# 49.7

# %%
# check max of Revenue (in millions)
df["Revenue (in millions)"].max()
# Out:
# 288189.0

# %%
# check range of Revenue (in millions)
df["Revenue (in millions)"].max() - df["Revenue (in millions)"].min()
# Out:
# 288139.3

# %%
# check variance of Revenue (in millions)
df["Revenue (in millions)"].var()
# Out:
# 128865292.56794204

# %%
# check sd of Revenue (in millions)
df["Revenue (in millions)"].std()
# Out:
# 11351.884978625445

# %%
# check q2 of Revenue (in millions)
df["Revenue (in millions)"].quantile(0.5)
# Out:
# 1019.0

# %%
# check q3 of Revenue (in millions)
Q3=df["Revenue (in millions)"].quantile(0.75)
Q3
# Out:
# 3871.0

# %%
# check q1 of Revenue (in millions)
Q1=df["Revenue (in millions)"].quantile(0.25)
Q1
# Out:
# 362.3

# %%
# check iqr of Revenue (in millions)
IQR=(Q3-Q1)
IQR
# Out:
# 3508.7

# %%
# check boxplot of Revenue (in millions)
plt.boxplot(df["Revenue (in millions)"])
plt.show()

# %% [markdown]
# **Computation of measures of shape of distribution**
#
# In this section, I will compute the measures of shape of distribution - skewness and kurtosis.
#
# Again, I will use the Revenue (in millions) variable for calculations.

# %%
# check skewness of Revenue (in millions)
df["Revenue (in millions)"].skew()
# Out:
# 9.32673729580641

# %% [markdown]
# **Interpretation**
#
# I find the skewness to be 9.3267. So, it is greater than 1. Hence, we can conclude that the Revenue (in millions) data is highly skewed.

# %%
# check kurtosis of Revenue (in millions)
df["Revenue (in millions)"].kurt()
# Out:
# 132.04561027793167

# %% [markdown]
# **Interpretation**
#
# I find the kurtosis to be 132.0456. So, it is greater than 3 and so excess kurtosis > 0. Hence, we can conclude that the Revenue (in millions) curve is a leptokurtic curve. As compared to a normal distribution, its central peak is higher and sharper, and its tails are longer and fatter.

# %% [markdown]
# **Results**
#
# 1) I have computed the measures of central tendency-mean, median and mode for the Revenue (in millions)variable. I have found mean > median > mode. So, the distribution of Revenue (in millions) is positively skewed. I have plotted its distribution to confirm the same.
#
# 2) I have computed the measures of dispersion or variability-range, variance, standard-deviation, median and IQR for the Revenue (in millions)variable.
#
# 3) I have also computed the measures of shape-skewness and kurtosis for the Revenue (in millions)variable.
#
# 4) I find the skewness to be 9.3267. So, it is greater than 1. Hence, we can conclude that the Revenue (in millions) data is highly skewed.
#
# 5) I find the kurtosis to be 132.0456. So, it is greater than 3 and so excess kurtosis > 0. Hence, we can conclude that the Revenue (in millions) curve is a leptokurtic curve. As compared to a normal distribution, its central peak is higher and sharper, and its tails are longer and fatter.
