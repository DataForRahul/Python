# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
plt.figure(figsize=(6,6))
plt.bar(["jan","feb","mar","Apr"],[22,33,41.5,44],width=0.3,label="mark1",color=["gold","black","olive","green"],log=True)
plt.legend()
plt.title("Bar Plot",color='red',size=11)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'jan'), Text(1, 0, 'feb'), Text(2, 0, 'mar'), Text(3, 0, 'Apr')])

# %%
month=["jan","feb","mar","Apr","may","jun","jul","aug","sep","oct","nov","dec"]
x=np.arange(0,len(month))-0.14
x_=np.arange(0,len(month))+0.25
x1=[18,23,33,43,32,56,76,88,91,78,51,29]
x2=[19,21,36,47,55,76,43,82,101,80,57,33]
plt.bar(x,x1,width=0.4,label="x1")
plt.bar(x_,x2,width=0.4,label="x2")
plt.legend()
plt.xticks(np.arange(0,len(month)),labels=month)
# Out:
# ([<matplotlib.axis.XTick at 0x7fd5016ed900>,
# ...
#  [Text(0, 0, 'jan'),
#   Text(1, 0, 'feb'),
#   Text(2, 0, 'mar'),
#   Text(3, 0, 'Apr'),
#   Text(4, 0, 'may'),
#   Text(5, 0, 'jun'),
#   Text(6, 0, 'jul'),
#   Text(7, 0, 'aug'),
#   Text(8, 0, 'sep'),
#   Text(9, 0, 'oct'),
#   Text(10, 0, 'nov'),
#   Text(11, 0, 'dec')])

# %%
plt.pie([22,34,56,78,92,111],labels=["A","B","C","D","E","F"],autopct="%1.1f%%",pctdistance=0.8,wedgeprops={"linewidth":1.2,"edgecolor":"black"})
plt.legend()

# %%
dat=np.random.normal(30,22.4,size=500)
uni=np.random.randint(10,545,size=400)
dat.sort()
dat
plt.hist(dat,bins=10,color="blue",histtype="step")
plt.hist(uni,bins=10,color="black",histtype="step")
plt.show()

# %%
b1=np.random.randint(10,1000,size=40)
b2=np.random.randint(10,1000,size=40)
b3=np.random.randint(10,1000,size=40)
b=[b1,b2,b3]
plt.boxplot(b,notch=True,labels=["a","b","c"])
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ap=np.random.randint(5,50,size=20)
ap1=np.random.randint(5,50,size=20)
plt.hist2d(ap,ap1,bins=50,cmap="cool")
plt.colorbar()

# %%
plt.figure(figsize=(6,6))
north=[23,29,33,39,44,51,58,88,97,111,128,130,150]
east=[21,28,38,44,49,52,59,67,77,87,100,109,141]
west=np.random.randint(18,170,size=13)
south=np.random.randint(18,172,size=13)
sales=np.random.randint(22,200,size=13)
plt.subplot(2,2,1)
plt.plot(sales,north,label="north")
plt.legend()
plt.subplot(2,2,2)
plt.plot(sales,east,label="east")
plt.legend()
plt.subplot(2,2,3)
plt.plot(sales,west,label="west")
plt.legend()
plt.subplot(2,2,4)
plt.plot(sales,south,label="south")
plt.legend()
plt.show()

# %%
fig,ax=plt.subplots(2,2,figsize=(3,3),sharex=True,sharey=True)
ax1=ax[0,0]
ax2=ax[0,1]
ax3=ax[1,0]
ax4=ax[1,1]
ax1.plot(np.random.randint(10,100,size=10),np.arange(12,50,4),label="First",color="green")
ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.legend()
ax2.plot(np.random.randint(10,100,size=10),np.arange(12,50,4),label="Second")
ax2.set_xlabel("X")
ax2.set_ylabel("Y")
ax2.legend()
ax3.plot(np.random.randint(10,100,size=10),np.arange(12,50,4),label="Third",color="gold")
ax3.set_xlabel("X")
ax3.set_ylabel("Y")
ax3.legend()
ax4.plot(np.random.randint(10,100,size=10),np.arange(12,50,4),label="Forth",color="pink")
ax4.set_xlabel("X")
ax4.set_ylabel("Y")
ax4.legend()
ax2.set_title("GRAPH")
plt.tight_layout()

# %%
an=pd.read_excel("/content/Financial_Sales.xlsx")
an
# Out:
#     Bill ID           Segment                   Country    Product  \
# 0    ID0001        Government                    Canada  Carretera
# 1    ID0002        Government                   Germany  Carretera
# 2    ID0003         Midmarket                    France  Carretera
# 3    ID0004         Midmarket                   Germany  Carretera
# 4    ID0005         Midmarket                    Mexico  Carretera
# ..      ...               ...                       ...        ...
# 695  ID0696    Small Business                    France   Amarilla
# 696  ID0697    Small Business                    Mexico   Amarilla
# 697  ID0698        Government                    Mexico    Montana
# 698  ID0699        Government                    Canada      Paseo
# 699  ID0700  Channel Partners  United States of America        VTT
#
#     Discount Band  Units Sold  Target Units  Manufacturing Price  Sale Price  \
# 0            None      1618.5        1493.5                    3          20
# ...

# %%
fig,ax=plt.subplots(figsize=(6,4))
ax1=ax.twinx()
ax.bar(an["Segment"],an["Units Sold"],color="gold")
ax1.plot(an["Segment"],an["Sale Price"])
ax.tick_params(axis="x",labelrotation=45)

# %%
x=np.linspace(0,4*np.pi,20)
x1=np.sin(x)
x2=2*x1
plt.plot(x,x1,marker="*",color="pink")
plt.plot(x,x2,marker="^",color="black")
plt.fill_between(x,x1,x2,color="red")
plt.show()

# %%
sbn.get_dataset_names()
iris=sbn.load_dataset("iris")

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.plot("sepal_width","sepal_length",kind="scatter",c="petal_length",colormap="cool",colorbar=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
sbn.scatterplot(x=iris.petal_length,y=iris.sepal_length,hue=iris.species)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
iris.plot(kind="kde",alpha=0.3)
# Out:
# <Axes: ylabel='Density'>

# %%
iris.plot(kind="hist",bins=60)
# Out:
# <Axes: ylabel='Frequency'>

# %%
pd.plotting.scatter_matrix(iris,color="gold",hist_kwds={"color":"red"})
plt.tight_layout()

# %%
pd.plotting.parallel_coordinates(iris,class_column="species",cols=["sepal_length","petal_width"])
# Out:
# <Axes: >

# %%
sbn.displot(iris,x="sepal_length",kde=True)

# %%
sbn.scatterplot(iris,x=iris.sepal_length,y=iris.sepal_width,hue="species",palette=["gold","b","r"])
sbn.rugplot(iris,x=iris.sepal_length,y=iris.sepal_width,hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sbn.jointplot(iris,x=iris.sepal_length,y=iris.sepal_width,kind="reg")

# %%
fig,ax1=plt.subplots(figsize=(3,3))
sbn.regplot(iris,x=iris.sepal_length,y=iris.sepal_width,ax=ax1)
sbn.scatterplot(iris,x=iris.sepal_length,y=iris.sepal_width,hue="species",palette=["gold","b","r"],ax=ax1)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sbn.pairplot(iris,size=1.1,hue="species",hue_order=["versicolor","setosa","virginica"],kind="kde",diag_kind="hist")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
pd.Series(iris[iris.species=="setosa"].sepal_length.value_counts())
# Out:
# 5.1    8
# 5.0    8
# 5.4    5
# 4.8    5
# 4.9    4
# 4.6    4
# 4.4    3
# 5.2    3
# 4.7    2
# 5.7    2
# 5.5    2
# 4.3    1
# 5.8    1
# 4.5    1
# 5.3    1
# Name: sepal_length, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.subplot(1,2,1)
sbn.swarmplot(iris,y=iris.sepal_length,hue="species")
plt.subplot(1,2,2)
sbn.violinplot(iris,y=iris.sepal_length,hue="species")
plt.tight_layout()

# %%
sbn.countplot(iris)
# Out:
# <Axes: ylabel='count'>

# %%
sbn.barplot(iris,y="sepal_length",x="species")
iris.mean()
# Out:
# <ipython-input-68-c89d9e5f7ca4>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
sbn.boxplot(iris,x="species",y="petal_length",palette="rainbow")
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
iris.groupby(by="species").median()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
x1=[2,4,6,8,10,12]
y1=[11,13,15,17,19,21]
plt.plot(x1,y1,linewidth=2,label="Chart1" ,markersize=6,color='green', marker='o', linestyle='dashdot')
plt.grid(axis="x")
plt.title("Line Chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
month=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
y=np.random.randint(15,300,12)
y1=np.random.randint(16,302,12)
plt.figure(figsize=(9,4))
x1=np.arange(1,len(month)+1)+0.22
x11=np.arange(1,len(month)+1)
x2=np.arange(1,len(month)+1)-0.21
plt.bar(x1,y,width=0.44,color=["gold"],label="Bar1")
plt.bar(x2,y1,width=0.44,color=["red"],label="Bar2")
plt.xticks(x11,labels=month,rotation=45)
plt.legend()
plt.show()

# %%
plt.pie(x=[12,19,30],labels=["a","b","c"],autopct="%1.2f%%")
plt.show()

# %%
x=np.random.normal(size=20)
x.sort()
x
# Out:
# array([-1.02915625, -1.0099898 , -0.64217545, -0.46444822, -0.44697704,
#        -0.42574352, -0.23549732, -0.12588937, -0.06116061, -0.05530276,
#         0.28331491,  0.32099953,  0.48281594,  0.53258468,  0.94736546,
#         1.01009442,  1.10727827,  1.42842099,  1.8269847 ,  1.93304207])

# %%
y=np.random.random(20)
y
# Out:
# array([0.16656379, 0.29458121, 0.03406332, 0.7730356 , 0.43218324,
#        0.68537904, 0.81978494, 0.16163325, 0.51834854, 0.23905614,
#        0.30999937, 0.20281745, 0.35759857, 0.23463097, 0.35706812,
#        0.44392037, 0.17391895, 0.42434117, 0.55466927, 0.19334366])

# %%
plt.hist(x,bins=7)
plt.hist(y,bins=7)
plt.show()

# %%
x1=np.random.randint(12,222,size=10)
x2=np.random.randint(12,222,size=10)
plt.boxplot(x1)
plt.show()

# %%
plt.hist2d(x1,x2,bins=15)
plt.colorbar()
plt.show()
plt.scatter(x1,x2)

# %%
north=np.random.randint(2,300,size=12)
east=np.random.randint(2,300,size=12)
west=np.random.randint(2,300,size=12)
south=np.random.randint(2,300,size=12)
month=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
plt.figure(figsize=(10,8))
plt.subplot(4,1,1)
plt.bar(month,north,color="r")
plt.title("A")
plt.xlabel("XX")
plt.subplot(4,1,2)
plt.bar(month,east)
plt.subplot(4,1,3)
plt.bar(month,west,color="gold")
plt.subplot(4,1,4)
plt.bar(month,south,color="pink")
plt.show()

# %%
fig,ax=plt.subplots(2,2,figsize=(6,6))
ax1=ax[0,0]
ax2=ax[0,1]
ax3=ax[1,0]
ax4=ax[1,1]
ax1.bar(month,north,color="r")
ax1.set_title("AA")
ax2.bar(month,east,label="east")
ax2.legend()
ax3.bar(month,west,color="gold")
ax3.set_ylabel("YY")
ax4.bar(month,south,color="pink")
ax4.legend()
plt.tight_layout()
plt.show()

# %%
imdb=pd.read_csv("/content/IMDB-Movie-Data.csv")
fig,ax=plt.subplots(figsize=(11,6))
ax2=ax.twinx()
ax.bar(x=imdb.Genre,height=imdb.Runtime_minutes)
ax2.plot(imdb.Genre,imdb.Year,color="gold")
ax.tick_params(axis="x",labelrotation=45)

# %%
x=np.linspace(0,4*np.pi,30)
x1=np.sin(x)
x2=2*np.sin(x)
plt.plot(x,x1,marker="o")
plt.plot(x,x2,marker="+")
plt.fill_between(x,x1,x2,color="pink")

# %%
plt.style.use("seaborn-v0_8")

# %%
iris=sbn.load_dataset("iris")

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.plot.scatter(x="sepal_length", y="petal_length",cmap="hsv",c="petal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot(kind="hist",alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.sepal_width.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sbn.kdeplot(data=iris)
# Out:
# <Axes: ylabel='Density'>

# %%
pd.plotting.parallel_coordinates(iris,class_column="species",cols=["sepal_length","petal_length"])
plt.tight_layout()

# %%
sbn.displot(iris,x="sepal_length",kde=True,rug=True)

# %%
sbn.rugplot(iris,x=iris.sepal_length,hue=iris.species,palette=["gold","pink","red"])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
sbn.jointplot(iris,x=iris.sepal_length,y=iris.petal_length,kind="kde",hue=iris.species)

# %%
fig,ax=plt.subplots(figsize=(3,3))
sbn.scatterplot(iris,x=iris.sepal_length,y=iris.petal_length,hue=iris.species,ax=ax)
sbn.kdeplot(iris,x=iris.sepal_length,y=iris.petal_length,hue=iris.species,ax=ax)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sbn.pairplot(iris,size=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris[iris.species=="setosa"].petal_length.value_counts().sort_values()
# Out:
# 1.1     1
# 1.0     1
# 1.2     2
# 1.9     2
# 1.7     4
# 1.3     7
# 1.6     7
# 1.4    13
# 1.5    13
# Name: petal_length, dtype: int64

# %%
plt.subplot(1,2,1)
sbn.violinplot(data=iris,x="species",y="petal_length")
plt.subplot(1,2,2)
sbn.swarmplot(data=iris,x="species",y="petal_length")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='species', ylabel='petal_length'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 44.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sbn.boxplot(y=iris[iris.species=="setosa"].sepal_length)
# Out:
# <Axes: ylabel='sepal_length'>

# %%
iris.groupby(by="species").mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026
